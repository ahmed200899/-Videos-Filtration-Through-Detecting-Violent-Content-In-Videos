# %%
import os
from random import shuffle

import cv2
import os
import numpy as np
import matplotlib.pyplot as plt


from keras import backend as K
from keras.models import Model, Sequential
from keras.layers import Input
from keras.layers import LSTM
from keras.layers import Dense, Activation
import sys
from keras.applications.vgg16 import VGG16


import h5py


import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %% [markdown]
# ****
#
# ---
#
# # functions

# %%
def get_frames(current_dir, file_name):
    
    in_file = os.path.join(current_dir, file_name)
    
    images = []
    
    vidcap = cv2.VideoCapture(in_file)
    
    success,image = vidcap.read()
        
    count = 0

    while count<_images_per_file:
                
        RGB_img = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    
        res = cv2.resize(RGB_img, dsize=(img_size, img_size),
                                 interpolation=cv2.INTER_CUBIC)
    
        images.append(res)
    
        success,image = vidcap.read()
    
        count += 1
        
    resul = np.array(images)
    
    resul = (resul / 255.).astype(np.float16)
        
    return resul

# %%
def label_video_names(in_dir):
    
    # list containing video names
    names = []
    # list containin video labels [1, 0] if it has violence and [0, 1] if not
    labels = []
    
    
    for current_dir, dir_names,file_names in os.walk(in_dir):
        
        for file_name in file_names:
            
            if file_name[0:2] == 'fi':
                labels.append([1,0])
                names.append(file_name)
            elif file_name[0:2] == 'no':
                labels.append([0,1])
                names.append(file_name)
                     
            
    c = list(zip(names,labels))
    # Suffle the data (names and labels)
    shuffle(c)
    
    names, labels = zip(*c)
            
    return names, labels

# %%
def get_transfer_values(current_dir, file_name):
    
    # Pre-allocate input-batch-array for images.
    shape = (_images_per_file,) + img_size_touple + (3,)
    
    image_batch = np.zeros(shape=shape, dtype=np.float16)
    
    image_batch = get_frames(current_dir, file_name)
      
    # Pre-allocate output-array for transfer-values.
    # Note that we use 16-bit floating-points to save memory.
    shape = (_images_per_file, transfer_values_size)
    transfer_values = np.zeros(shape=shape, dtype=np.float16)

    transfer_values = \
            image_model_transfer.predict(image_batch)
            
    return transfer_values

# %%
def proces_transfer(vid_names, in_dir, labels):
    
    count = 0
    
    tam = len(vid_names)
    
    # Pre-allocate input-batch-array for images.
    shape = (_images_per_file,) + img_size_touple + (3,)
    
    while count<tam:
        
        video_name = vid_names[count]
        
        image_batch = np.zeros(shape=shape, dtype=np.float16)
    
        image_batch = get_frames(in_dir, video_name)
        
         # Note that we use 16-bit floating-points to save memory.
        shape = (_images_per_file, transfer_values_size)
        transfer_values = np.zeros(shape=shape, dtype=np.float16)
        
        transfer_values = \
            image_model_transfer.predict(image_batch)
         
        labels1 = labels[count]
        
        aux = np.ones([20,2])
        
        labelss = labels1*aux
        
        yield transfer_values, labelss
        
        count+=1

# %%
def make_files(n_files):
    
    gen = proces_transfer(names_training, in_dir_prueba, labels_training)

    numer = 1

    # Read the first chunk to get the column dtypes
    chunk = next(gen)

    row_count = chunk[0].shape[0]
    row_count2 = chunk[1].shape[0]
    
    with h5py.File('prueba.h5', 'w') as f:
    
        # Initialize a resizable dataset to hold the output
        maxshape = (None,) + chunk[0].shape[1:]
        maxshape2 = (None,) + chunk[1].shape[1:]
    
    
        dset = f.create_dataset('data', shape=chunk[0].shape, maxshape=maxshape,
                                chunks=chunk[0].shape, dtype=chunk[0].dtype)
    
        dset2 = f.create_dataset('labels', shape=chunk[1].shape, maxshape=maxshape2,
                                 chunks=chunk[1].shape, dtype=chunk[1].dtype)
    
         # Write the first chunk of rows
        dset[:] = chunk[0]
        dset2[:] = chunk[1]

        for chunk in gen:
            
            if numer == n_files:
            
                break

            # Resize the dataset to accommodate the next chunk of rows
            dset.resize(row_count + chunk[0].shape[0], axis=0)
            dset2.resize(row_count2 + chunk[1].shape[0], axis=0)

            # Write the next chunk
            dset[row_count:] = chunk[0]
            dset2[row_count:] = chunk[1]

            # Increment the row count
            row_count += chunk[0].shape[0]
            row_count2 += chunk[1].shape[0]
            
            print_progress(numer, n_files)
        
            
            
            numer += 1

# %%
def make_files_test(n_files):
    
    gen = proces_transfer(names_test, in_dir, labels_test)

    numer = 1

    # Read the first chunk to get the column dtypes
    chunk = next(gen)

    row_count = chunk[0].shape[0]
    row_count2 = chunk[1].shape[0]
    
    with h5py.File('pruebavalidation.h5', 'w') as f:
    
        # Initialize a resizable dataset to hold the output
        maxshape = (None,) + chunk[0].shape[1:]
        maxshape2 = (None,) + chunk[1].shape[1:]
    
    
        dset = f.create_dataset('data', shape=chunk[0].shape, maxshape=maxshape,
                                chunks=chunk[0].shape, dtype=chunk[0].dtype)
    
        dset2 = f.create_dataset('labels', shape=chunk[1].shape, maxshape=maxshape2,
                                 chunks=chunk[1].shape, dtype=chunk[1].dtype)
    
         # Write the first chunk of rows
        dset[:] = chunk[0]
        dset2[:] = chunk[1]

        for chunk in gen:
            
            if numer == n_files:
            
                break

            # Resize the dataset to accommodate the next chunk of rows
            dset.resize(row_count + chunk[0].shape[0], axis=0)
            dset2.resize(row_count2 + chunk[1].shape[0], axis=0)

            # Write the next chunk
            dset[row_count:] = chunk[0]
            dset2[row_count:] = chunk[1]

            # Increment the row count
            row_count += chunk[0].shape[0]
            row_count2 += chunk[1].shape[0]
            
            print_progress(numer, n_files)
        
            numer += 1

# %%
def print_progress(count, max_count):
    # Percentage completion.
    pct_complete = count / max_count

    # Status-message. Note the \r which means the line should
    # overwrite itself.
    msg = "\r- Progress: {0:.1%}".format(pct_complete)

    # Print it.
    sys.stdout.write(msg)
    sys.stdout.flush()

# %%
def process_alldata_training():
    
    joint_transfer=[]
    frames_num=20
    count = 0
    
    with h5py.File('prueba.h5', 'r') as f:
            
        X_batch = f['data'][:]
        y_batch = f['labels'][:]

    for i in range(int(len(X_batch)/frames_num)):
        inc = count+frames_num
        joint_transfer.append([X_batch[count:inc],y_batch[count]])
        count =inc
        
    data =[]
    target=[]
    
    for i in joint_transfer:
        data.append(i[0])
        target.append(np.array(i[1]))
        
    return data, target

# %%
def process_alldata_test():
    
    joint_transfer=[]
    frames_num=20
    count = 0
    
    with h5py.File('pruebavalidation.h5', 'r') as f:
            
        X_batch = f['data'][:]
        y_batch = f['labels'][:]

    for i in range(int(len(X_batch)/frames_num)):
        inc = count+frames_num
        joint_transfer.append([X_batch[count:inc],y_batch[count]])
        count =inc
        
    data =[]
    target=[]
    
    for i in joint_transfer:
        data.append(i[0])
        target.append(np.array(i[1]))
        
    return data, target

# %%
# Frame size  
img_size = 224

img_size_touple = (img_size, img_size)

# Number of channels (RGB)
num_channels = 3

# Flat frame size
img_size_flat = img_size * img_size * num_channels

# Number of classes for classification (Violence-No Violence)
num_classes = 2

# Number of files to train
_num_files_train = 1

# Number of frames per video
_images_per_file = 20

# Number of frames per training set
_num_images_train = _num_files_train * _images_per_file

# Video extension
video_exts = ".avi"

# %% [markdown]
# ## Importing data

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
in_dir = "/content/drive/MyDrive/GP/Data_set/N_ HockyFights/HockeyFights"
in_dir_prueba =  "/content/drive/MyDrive/GP/Data_set/N_ HockyFights/HockeyFights"
names, labels = label_video_names(in_dir)

# %%
image_model = VGG16(include_top=True, weights='imagenet')
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels.h5
# 553467904/553467096 [==============================] - 5s 0us/step
# 553476096/553467096 [==============================] - 5s 0us/step

# %%
image_model.summary()
# Out:
# Model: "vgg16"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 56, 56, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 28, 28, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 28, 28, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 14, 14, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 7, 7, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 25088)             0
# _________________________________________________________________
# fc1 (Dense)                  (None, 4096)              102764544
# _________________________________________________________________
# fc2 (Dense)                  (None, 4096)              16781312
# _________________________________________________________________
# predictions (Dense)          (None, 1000)              4097000
# =================================================================
# Total params: 138,357,544
# Trainable params: 138,357,544
# Non-trainable params: 0
# _________________________________________________________________

# %%
input_shape = image_model.layers[0].output_shape[1:3]
input_shape
# Out:
# []

# %%
transfer_layer = image_model.get_layer('fc2')

image_model_transfer = Model(inputs=image_model.input,
                             outputs=transfer_layer.output)

transfer_values_size = K.int_shape(transfer_layer.output)[1]


print("The input of the VGG16 net have dimensions:",K.int_shape(image_model.input)[1:3])

print("The output of the selecter layer of VGG16 net have dimensions: ", transfer_values_size)
# Out:
# The input of the VGG16 net have dimensions: (224, 224)
# The output of the selecter layer of VGG16 net have dimensions:  4096

# %%
transfer_layer

# %%
training_set = int(len(names)*0.8)
test_set = int(len(names)*0.2)

names_training = names[0:training_set]
names_test = names[training_set:]

labels_training = labels[0:training_set]
labels_test = labels[training_set:]

# %%
make_files(training_set)
# Out:
# - Progress: 99.9%

# %%
make_files_test(test_set)
# Out:
# - Progress: 99.5%

# %%
data, target = process_alldata_training()
data_test, target_test = process_alldata_test()

# %%
chunk_size = 4096
n_chunks = 20
rnn_size = 512

model = Sequential()
model.add(LSTM(rnn_size, input_shape=(n_chunks, chunk_size)))
model.add(Dense(1024))
model.add(Activation('relu'))
model.add(Dense(50))
model.add(Activation('relu'))
model.add(Dense(2))
model.add(Activation('softmax'))
model.compile(loss='mean_squared_error', optimizer='adam',metrics=['accuracy'])

# %%
epoch = 200
batchS = 500

history = model.fit(np.array(data[0:750]), np.array(target[0:750]), epochs=epoch,
                    validation_data=(np.array(data[750:]), np.array(target[750:])), 
                    batch_size=batchS, verbose=2)
# Out:
# Epoch 1/200
# 2/2 - 0s - loss: 0.0595 - accuracy: 0.9293 - val_loss: 0.0717 - val_accuracy: 0.9000
# Epoch 2/200
# 2/2 - 0s - loss: 0.0561 - accuracy: 0.9400 - val_loss: 0.0698 - val_accuracy: 0.9000
# Epoch 3/200
# 2/2 - 0s - loss: 0.0541 - accuracy: 0.9413 - val_loss: 0.0846 - val_accuracy: 0.9000
# Epoch 4/200
# 2/2 - 0s - loss: 0.0592 - accuracy: 0.9280 - val_loss: 0.0703 - val_accuracy: 0.9000
# Epoch 5/200
# 2/2 - 0s - loss: 0.0543 - accuracy: 0.9400 - val_loss: 0.0741 - val_accuracy: 0.9000
# Epoch 6/200
# 2/2 - 0s - loss: 0.0533 - accuracy: 0.9373 - val_loss: 0.0775 - val_accuracy: 0.9000
# Epoch 7/200
# 2/2 - 0s - loss: 0.0534 - accuracy: 0.9387 - val_loss: 0.0760 - val_accuracy: 0.9000
# Epoch 8/200
# 2/2 - 0s - loss: 0.0524 - accuracy: 0.9400 - val_loss: 0.0782 - val_accuracy: 0.9000
# Epoch 9/200
# 2/2 - 0s - loss: 0.0524 - accuracy: 0.9387 - val_loss: 0.0739 - val_accuracy: 0.9000
# Epoch 10/200
# 2/2 - 0s - loss: 0.0517 - accuracy: 0.9400 - val_loss: 0.0747 - val_accuracy: 0.9000
# Epoch 11/200
# 2/2 - 0s - loss: 0.0512 - accuracy: 0.9400 - val_loss: 0.0707 - val_accuracy: 0.9000
# Epoch 12/200
# 2/2 - 0s - loss: 0.0522 - accuracy: 0.9413 - val_loss: 0.0692 - val_accuracy: 0.9000
# Epoch 13/200
# 2/2 - 0s - loss: 0.0515 - accuracy: 0.9440 - val_loss: 0.0750 - val_accuracy: 0.9000
# Epoch 14/200
# 2/2 - 0s - loss: 0.0515 - accuracy: 0.9427 - val_loss: 0.0688 - val_accuracy: 0.9000
# Epoch 15/200
# 2/2 - 0s - loss: 0.0518 - accuracy: 0.9400 - val_loss: 0.0731 - val_accuracy: 0.9000
# Epoch 16/200
# 2/2 - 0s - loss: 0.0504 - accuracy: 0.9427 - val_loss: 0.0758 - val_accuracy: 0.9000
# Epoch 17/200
# 2/2 - 0s - loss: 0.0507 - accuracy: 0.9453 - val_loss: 0.0671 - val_accuracy: 0.9000
# Epoch 18/200
# 2/2 - 0s - loss: 0.0519 - accuracy: 0.9413 - val_loss: 0.0677 - val_accuracy: 0.9000
# Epoch 19/200
# 2/2 - 0s - loss: 0.0506 - accuracy: 0.9427 - val_loss: 0.0742 - val_accuracy: 0.9000
# Epoch 20/200
# 2/2 - 0s - loss: 0.0528 - accuracy: 0.9387 - val_loss: 0.0640 - val_accuracy: 0.9200
# Epoch 21/200
# 2/2 - 0s - loss: 0.0519 - accuracy: 0.9427 - val_loss: 0.0705 - val_accuracy: 0.9000
# Epoch 22/200
# 2/2 - 0s - loss: 0.0508 - accuracy: 0.9413 - val_loss: 0.0694 - val_accuracy: 0.9000
# Epoch 23/200
# 2/2 - 0s - loss: 0.0503 - accuracy: 0.9427 - val_loss: 0.0682 - val_accuracy: 0.9000
# Epoch 24/200
# 2/2 - 0s - loss: 0.0487 - accuracy: 0.9453 - val_loss: 0.0745 - val_accuracy: 0.9000
# Epoch 25/200
# 2/2 - 0s - loss: 0.0489 - accuracy: 0.9453 - val_loss: 0.0639 - val_accuracy: 0.9200
# Epoch 26/200
# 2/2 - 0s - loss: 0.0483 - accuracy: 0.9467 - val_loss: 0.0757 - val_accuracy: 0.9000
# Epoch 27/200
# 2/2 - 0s - loss: 0.0500 - accuracy: 0.9453 - val_loss: 0.0619 - val_accuracy: 0.9200
# Epoch 28/200
# 2/2 - 0s - loss: 0.0516 - accuracy: 0.9440 - val_loss: 0.0763 - val_accuracy: 0.9000
# Epoch 29/200
# 2/2 - 0s - loss: 0.0517 - accuracy: 0.9427 - val_loss: 0.0669 - val_accuracy: 0.9200
# Epoch 30/200
# 2/2 - 0s - loss: 0.0495 - accuracy: 0.9427 - val_loss: 0.0712 - val_accuracy: 0.9000
# Epoch 31/200
# 2/2 - 0s - loss: 0.0532 - accuracy: 0.9347 - val_loss: 0.0619 - val_accuracy: 0.9200
# Epoch 32/200
# 2/2 - 0s - loss: 0.0536 - accuracy: 0.9373 - val_loss: 0.0732 - val_accuracy: 0.9000
# Epoch 33/200
# 2/2 - 0s - loss: 0.0564 - accuracy: 0.9373 - val_loss: 0.0621 - val_accuracy: 0.9200
# Epoch 34/200
# 2/2 - 0s - loss: 0.0614 - accuracy: 0.9293 - val_loss: 0.0847 - val_accuracy: 0.9200
# Epoch 35/200
# 2/2 - 0s - loss: 0.0687 - accuracy: 0.9133 - val_loss: 0.0691 - val_accuracy: 0.9200
# Epoch 36/200
# 2/2 - 0s - loss: 0.0552 - accuracy: 0.9333 - val_loss: 0.0658 - val_accuracy: 0.9200
# Epoch 37/200
# 2/2 - 0s - loss: 0.0530 - accuracy: 0.9373 - val_loss: 0.0718 - val_accuracy: 0.9000
# Epoch 38/200
# 2/2 - 0s - loss: 0.0487 - accuracy: 0.9453 - val_loss: 0.0623 - val_accuracy: 0.9200
# Epoch 39/200
# 2/2 - 0s - loss: 0.0522 - accuracy: 0.9413 - val_loss: 0.0697 - val_accuracy: 0.9200
# Epoch 40/200
# 2/2 - 0s - loss: 0.0464 - accuracy: 0.9493 - val_loss: 0.0648 - val_accuracy: 0.9200
# Epoch 41/200
# 2/2 - 0s - loss: 0.0468 - accuracy: 0.9493 - val_loss: 0.0703 - val_accuracy: 0.9200
# Epoch 42/200
# 2/2 - 0s - loss: 0.0464 - accuracy: 0.9493 - val_loss: 0.0693 - val_accuracy: 0.9200
# Epoch 43/200
# 2/2 - 0s - loss: 0.0465 - accuracy: 0.9467 - val_loss: 0.0675 - val_accuracy: 0.9200
# Epoch 44/200
# 2/2 - 0s - loss: 0.0456 - accuracy: 0.9493 - val_loss: 0.0675 - val_accuracy: 0.9200
# Epoch 45/200
# 2/2 - 0s - loss: 0.0458 - accuracy: 0.9493 - val_loss: 0.0666 - val_accuracy: 0.9200
# Epoch 46/200
# 2/2 - 0s - loss: 0.0456 - accuracy: 0.9493 - val_loss: 0.0689 - val_accuracy: 0.9200
# Epoch 47/200
# 2/2 - 0s - loss: 0.0444 - accuracy: 0.9520 - val_loss: 0.0629 - val_accuracy: 0.9200
# Epoch 48/200
# 2/2 - 0s - loss: 0.0468 - accuracy: 0.9480 - val_loss: 0.0686 - val_accuracy: 0.9200
# Epoch 49/200
# 2/2 - 0s - loss: 0.0442 - accuracy: 0.9493 - val_loss: 0.0665 - val_accuracy: 0.9200
# Epoch 50/200
# 2/2 - 0s - loss: 0.0438 - accuracy: 0.9520 - val_loss: 0.0650 - val_accuracy: 0.9200
# Epoch 51/200
# 2/2 - 0s - loss: 0.0444 - accuracy: 0.9507 - val_loss: 0.0664 - val_accuracy: 0.9200
# Epoch 52/200
# 2/2 - 0s - loss: 0.0439 - accuracy: 0.9493 - val_loss: 0.0639 - val_accuracy: 0.9200
# Epoch 53/200
# 2/2 - 0s - loss: 0.0443 - accuracy: 0.9493 - val_loss: 0.0680 - val_accuracy: 0.9200
# Epoch 54/200
# 2/2 - 0s - loss: 0.0433 - accuracy: 0.9507 - val_loss: 0.0655 - val_accuracy: 0.9200
# Epoch 55/200
# 2/2 - 0s - loss: 0.0430 - accuracy: 0.9533 - val_loss: 0.0671 - val_accuracy: 0.9200
# Epoch 56/200
# 2/2 - 0s - loss: 0.0447 - accuracy: 0.9493 - val_loss: 0.0630 - val_accuracy: 0.9200
# Epoch 57/200
# 2/2 - 0s - loss: 0.0444 - accuracy: 0.9520 - val_loss: 0.0686 - val_accuracy: 0.9200
# Epoch 58/200
# 2/2 - 0s - loss: 0.0437 - accuracy: 0.9533 - val_loss: 0.0665 - val_accuracy: 0.9200
# Epoch 59/200
# 2/2 - 0s - loss: 0.0423 - accuracy: 0.9547 - val_loss: 0.0646 - val_accuracy: 0.9200
# Epoch 60/200
# 2/2 - 0s - loss: 0.0428 - accuracy: 0.9560 - val_loss: 0.0687 - val_accuracy: 0.9200
# Epoch 61/200
# 2/2 - 0s - loss: 0.0417 - accuracy: 0.9560 - val_loss: 0.0608 - val_accuracy: 0.9000
# Epoch 62/200
# 2/2 - 0s - loss: 0.0440 - accuracy: 0.9533 - val_loss: 0.0691 - val_accuracy: 0.9200
# Epoch 63/200
# 2/2 - 0s - loss: 0.0422 - accuracy: 0.9547 - val_loss: 0.0627 - val_accuracy: 0.9200
# Epoch 64/200
# 2/2 - 0s - loss: 0.0423 - accuracy: 0.9533 - val_loss: 0.0705 - val_accuracy: 0.9200
# Epoch 65/200
# 2/2 - 0s - loss: 0.0474 - accuracy: 0.9467 - val_loss: 0.0582 - val_accuracy: 0.9200
# Epoch 66/200
# 2/2 - 0s - loss: 0.0519 - accuracy: 0.9387 - val_loss: 0.0729 - val_accuracy: 0.9000
# Epoch 67/200
# 2/2 - 0s - loss: 0.0554 - accuracy: 0.9320 - val_loss: 0.0608 - val_accuracy: 0.9200
# Epoch 68/200
# 2/2 - 0s - loss: 0.0467 - accuracy: 0.9493 - val_loss: 0.0688 - val_accuracy: 0.9200
# Epoch 69/200
# 2/2 - 0s - loss: 0.0422 - accuracy: 0.9560 - val_loss: 0.0592 - val_accuracy: 0.9000
# Epoch 70/200
# 2/2 - 0s - loss: 0.0444 - accuracy: 0.9520 - val_loss: 0.0704 - val_accuracy: 0.9200
# Epoch 71/200
# 2/2 - 0s - loss: 0.0450 - accuracy: 0.9533 - val_loss: 0.0573 - val_accuracy: 0.9200
# Epoch 72/200
# 2/2 - 0s - loss: 0.0452 - accuracy: 0.9507 - val_loss: 0.0700 - val_accuracy: 0.9200
# Epoch 73/200
# 2/2 - 0s - loss: 0.0442 - accuracy: 0.9520 - val_loss: 0.0631 - val_accuracy: 0.9200
# Epoch 74/200
# 2/2 - 0s - loss: 0.0413 - accuracy: 0.9547 - val_loss: 0.0681 - val_accuracy: 0.9200
# Epoch 75/200
# 2/2 - 0s - loss: 0.0407 - accuracy: 0.9560 - val_loss: 0.0628 - val_accuracy: 0.9200
# Epoch 76/200
# 2/2 - 0s - loss: 0.0439 - accuracy: 0.9520 - val_loss: 0.0712 - val_accuracy: 0.9200
# Epoch 77/200
# 2/2 - 0s - loss: 0.0486 - accuracy: 0.9467 - val_loss: 0.0569 - val_accuracy: 0.9200
# Epoch 78/200
# 2/2 - 0s - loss: 0.0488 - accuracy: 0.9453 - val_loss: 0.0719 - val_accuracy: 0.9200
# Epoch 79/200
# 2/2 - 0s - loss: 0.0491 - accuracy: 0.9440 - val_loss: 0.0575 - val_accuracy: 0.9000
# Epoch 80/200
# 2/2 - 0s - loss: 0.0539 - accuracy: 0.9360 - val_loss: 0.0948 - val_accuracy: 0.8800
# Epoch 81/200
# 2/2 - 0s - loss: 0.0824 - accuracy: 0.9000 - val_loss: 0.0607 - val_accuracy: 0.9200
# Epoch 82/200
# 2/2 - 0s - loss: 0.0635 - accuracy: 0.9213 - val_loss: 0.0579 - val_accuracy: 0.9200
# Epoch 83/200
# 2/2 - 0s - loss: 0.0556 - accuracy: 0.9347 - val_loss: 0.0880 - val_accuracy: 0.9000
# Epoch 84/200
# 2/2 - 0s - loss: 0.0651 - accuracy: 0.9200 - val_loss: 0.0625 - val_accuracy: 0.9200
# Epoch 85/200
# 2/2 - 0s - loss: 0.0588 - accuracy: 0.9280 - val_loss: 0.0758 - val_accuracy: 0.9200
# Epoch 86/200
# 2/2 - 0s - loss: 0.0516 - accuracy: 0.9333 - val_loss: 0.0647 - val_accuracy: 0.9200
# Epoch 87/200
# 2/2 - 0s - loss: 0.0449 - accuracy: 0.9480 - val_loss: 0.0656 - val_accuracy: 0.9200
# Epoch 88/200
# 2/2 - 0s - loss: 0.0433 - accuracy: 0.9520 - val_loss: 0.0714 - val_accuracy: 0.9000
# Epoch 89/200
# 2/2 - 0s - loss: 0.0439 - accuracy: 0.9520 - val_loss: 0.0609 - val_accuracy: 0.9200
# Epoch 90/200
# 2/2 - 0s - loss: 0.0459 - accuracy: 0.9493 - val_loss: 0.0683 - val_accuracy: 0.9200
# Epoch 91/200
# 2/2 - 0s - loss: 0.0427 - accuracy: 0.9520 - val_loss: 0.0689 - val_accuracy: 0.9200
# Epoch 92/200
# 2/2 - 0s - loss: 0.0411 - accuracy: 0.9547 - val_loss: 0.0640 - val_accuracy: 0.9200
# Epoch 93/200
# 2/2 - 0s - loss: 0.0419 - accuracy: 0.9547 - val_loss: 0.0700 - val_accuracy: 0.9200
# Epoch 94/200
# 2/2 - 0s - loss: 0.0425 - accuracy: 0.9547 - val_loss: 0.0690 - val_accuracy: 0.9200
# Epoch 95/200
# 2/2 - 0s - loss: 0.0401 - accuracy: 0.9573 - val_loss: 0.0670 - val_accuracy: 0.9200
# Epoch 96/200
# 2/2 - 0s - loss: 0.0397 - accuracy: 0.9573 - val_loss: 0.0698 - val_accuracy: 0.9200
# Epoch 97/200
# 2/2 - 0s - loss: 0.0409 - accuracy: 0.9547 - val_loss: 0.0690 - val_accuracy: 0.9200
# Epoch 98/200
# 2/2 - 0s - loss: 0.0389 - accuracy: 0.9587 - val_loss: 0.0668 - val_accuracy: 0.9200
# Epoch 99/200
# 2/2 - 0s - loss: 0.0392 - accuracy: 0.9573 - val_loss: 0.0698 - val_accuracy: 0.9200
# Epoch 100/200
# 2/2 - 0s - loss: 0.0389 - accuracy: 0.9573 - val_loss: 0.0692 - val_accuracy: 0.9200
# Epoch 101/200
# 2/2 - 0s - loss: 0.0381 - accuracy: 0.9587 - val_loss: 0.0654 - val_accuracy: 0.9200
# Epoch 102/200
# 2/2 - 0s - loss: 0.0397 - accuracy: 0.9560 - val_loss: 0.0703 - val_accuracy: 0.9200
# Epoch 103/200
# 2/2 - 0s - loss: 0.0408 - accuracy: 0.9600 - val_loss: 0.0691 - val_accuracy: 0.9200
# Epoch 104/200
# 2/2 - 0s - loss: 0.0383 - accuracy: 0.9573 - val_loss: 0.0647 - val_accuracy: 0.9200
# Epoch 105/200
# 2/2 - 0s - loss: 0.0377 - accuracy: 0.9587 - val_loss: 0.0706 - val_accuracy: 0.9200
# Epoch 106/200
# 2/2 - 0s - loss: 0.0412 - accuracy: 0.9560 - val_loss: 0.0659 - val_accuracy: 0.9200
# Epoch 107/200
# 2/2 - 0s - loss: 0.0386 - accuracy: 0.9600 - val_loss: 0.0696 - val_accuracy: 0.9200
# Epoch 108/200
# 2/2 - 0s - loss: 0.0383 - accuracy: 0.9600 - val_loss: 0.0696 - val_accuracy: 0.9200
# Epoch 109/200
# 2/2 - 0s - loss: 0.0372 - accuracy: 0.9600 - val_loss: 0.0640 - val_accuracy: 0.9200
# Epoch 110/200
# 2/2 - 0s - loss: 0.0376 - accuracy: 0.9613 - val_loss: 0.0709 - val_accuracy: 0.9200
# Epoch 111/200
# 2/2 - 0s - loss: 0.0380 - accuracy: 0.9613 - val_loss: 0.0600 - val_accuracy: 0.9200
# Epoch 112/200
# 2/2 - 0s - loss: 0.0409 - accuracy: 0.9533 - val_loss: 0.0701 - val_accuracy: 0.9200
# Epoch 113/200
# 2/2 - 0s - loss: 0.0366 - accuracy: 0.9613 - val_loss: 0.0692 - val_accuracy: 0.9200
# Epoch 114/200
# 2/2 - 0s - loss: 0.0361 - accuracy: 0.9627 - val_loss: 0.0694 - val_accuracy: 0.9200
# Epoch 115/200
# 2/2 - 0s - loss: 0.0359 - accuracy: 0.9627 - val_loss: 0.0677 - val_accuracy: 0.9200
# Epoch 116/200
# 2/2 - 0s - loss: 0.0358 - accuracy: 0.9640 - val_loss: 0.0685 - val_accuracy: 0.9200
# Epoch 117/200
# 2/2 - 0s - loss: 0.0360 - accuracy: 0.9613 - val_loss: 0.0700 - val_accuracy: 0.9200
# Epoch 118/200
# 2/2 - 0s - loss: 0.0361 - accuracy: 0.9613 - val_loss: 0.0662 - val_accuracy: 0.9200
# Epoch 119/200
# 2/2 - 0s - loss: 0.0356 - accuracy: 0.9640 - val_loss: 0.0668 - val_accuracy: 0.9200
# Epoch 120/200
# 2/2 - 0s - loss: 0.0353 - accuracy: 0.9627 - val_loss: 0.0697 - val_accuracy: 0.9200
# Epoch 121/200
# 2/2 - 0s - loss: 0.0350 - accuracy: 0.9627 - val_loss: 0.0595 - val_accuracy: 0.9400
# Epoch 122/200
# 2/2 - 0s - loss: 0.0396 - accuracy: 0.9573 - val_loss: 0.0719 - val_accuracy: 0.9200
# Epoch 123/200
# 2/2 - 0s - loss: 0.0375 - accuracy: 0.9613 - val_loss: 0.0581 - val_accuracy: 0.9400
# Epoch 124/200
# 2/2 - 0s - loss: 0.0374 - accuracy: 0.9573 - val_loss: 0.0735 - val_accuracy: 0.9000
# Epoch 125/200
# 2/2 - 0s - loss: 0.0440 - accuracy: 0.9507 - val_loss: 0.0578 - val_accuracy: 0.9400
# Epoch 126/200
# 2/2 - 0s - loss: 0.0432 - accuracy: 0.9507 - val_loss: 0.0729 - val_accuracy: 0.9200
# Epoch 127/200
# 2/2 - 0s - loss: 0.0383 - accuracy: 0.9613 - val_loss: 0.0602 - val_accuracy: 0.9200
# Epoch 128/200
# 2/2 - 0s - loss: 0.0584 - accuracy: 0.9213 - val_loss: 0.0998 - val_accuracy: 0.8800
# Epoch 129/200
# 2/2 - 0s - loss: 0.0592 - accuracy: 0.9267 - val_loss: 0.0920 - val_accuracy: 0.8800
# Epoch 130/200
# 2/2 - 0s - loss: 0.0888 - accuracy: 0.8947 - val_loss: 0.0797 - val_accuracy: 0.9000
# Epoch 131/200
# 2/2 - 0s - loss: 0.0545 - accuracy: 0.9320 - val_loss: 0.0558 - val_accuracy: 0.9400
# Epoch 132/200
# 2/2 - 0s - loss: 0.0498 - accuracy: 0.9440 - val_loss: 0.0711 - val_accuracy: 0.9200
# Epoch 133/200
# 2/2 - 0s - loss: 0.0423 - accuracy: 0.9547 - val_loss: 0.0696 - val_accuracy: 0.9200
# Epoch 134/200
# 2/2 - 0s - loss: 0.0369 - accuracy: 0.9600 - val_loss: 0.0649 - val_accuracy: 0.9200
# Epoch 135/200
# 2/2 - 0s - loss: 0.0371 - accuracy: 0.9627 - val_loss: 0.0705 - val_accuracy: 0.9200
# Epoch 136/200
# 2/2 - 0s - loss: 0.0373 - accuracy: 0.9613 - val_loss: 0.0654 - val_accuracy: 0.9200
# Epoch 137/200
# 2/2 - 0s - loss: 0.0374 - accuracy: 0.9600 - val_loss: 0.0682 - val_accuracy: 0.9200
# Epoch 138/200
# 2/2 - 0s - loss: 0.0357 - accuracy: 0.9640 - val_loss: 0.0710 - val_accuracy: 0.9200
# Epoch 139/200
# 2/2 - 0s - loss: 0.0357 - accuracy: 0.9627 - val_loss: 0.0665 - val_accuracy: 0.9200
# Epoch 140/200
# 2/2 - 0s - loss: 0.0362 - accuracy: 0.9627 - val_loss: 0.0699 - val_accuracy: 0.9200
# Epoch 141/200
# 2/2 - 0s - loss: 0.0349 - accuracy: 0.9627 - val_loss: 0.0713 - val_accuracy: 0.9200
# Epoch 142/200
# 2/2 - 0s - loss: 0.0355 - accuracy: 0.9627 - val_loss: 0.0685 - val_accuracy: 0.9200
# Epoch 143/200
# 2/2 - 0s - loss: 0.0350 - accuracy: 0.9640 - val_loss: 0.0691 - val_accuracy: 0.9200
# Epoch 144/200
# 2/2 - 0s - loss: 0.0343 - accuracy: 0.9640 - val_loss: 0.0712 - val_accuracy: 0.9200
# Epoch 145/200
# 2/2 - 0s - loss: 0.0347 - accuracy: 0.9627 - val_loss: 0.0654 - val_accuracy: 0.9200
# Epoch 146/200
# 2/2 - 0s - loss: 0.0343 - accuracy: 0.9640 - val_loss: 0.0693 - val_accuracy: 0.9200
# Epoch 147/200
# 2/2 - 0s - loss: 0.0339 - accuracy: 0.9627 - val_loss: 0.0688 - val_accuracy: 0.9200
# Epoch 148/200
# 2/2 - 0s - loss: 0.0339 - accuracy: 0.9640 - val_loss: 0.0677 - val_accuracy: 0.9200
# Epoch 149/200
# 2/2 - 0s - loss: 0.0332 - accuracy: 0.9667 - val_loss: 0.0687 - val_accuracy: 0.9200
# Epoch 150/200
# 2/2 - 0s - loss: 0.0331 - accuracy: 0.9667 - val_loss: 0.0612 - val_accuracy: 0.9200
# Epoch 151/200
# 2/2 - 0s - loss: 0.0338 - accuracy: 0.9640 - val_loss: 0.0684 - val_accuracy: 0.9200
# Epoch 152/200
# 2/2 - 0s - loss: 0.0333 - accuracy: 0.9667 - val_loss: 0.0621 - val_accuracy: 0.9200
# Epoch 153/200
# 2/2 - 0s - loss: 0.0334 - accuracy: 0.9653 - val_loss: 0.0675 - val_accuracy: 0.9200
# Epoch 154/200
# 2/2 - 0s - loss: 0.0333 - accuracy: 0.9667 - val_loss: 0.0689 - val_accuracy: 0.9200
# Epoch 155/200
# 2/2 - 0s - loss: 0.0331 - accuracy: 0.9653 - val_loss: 0.0650 - val_accuracy: 0.9200
# Epoch 156/200
# 2/2 - 0s - loss: 0.0325 - accuracy: 0.9680 - val_loss: 0.0700 - val_accuracy: 0.9200
# Epoch 157/200
# 2/2 - 0s - loss: 0.0328 - accuracy: 0.9667 - val_loss: 0.0598 - val_accuracy: 0.9400
# Epoch 158/200
# 2/2 - 0s - loss: 0.0349 - accuracy: 0.9653 - val_loss: 0.0711 - val_accuracy: 0.9200
# Epoch 159/200
# 2/2 - 0s - loss: 0.0331 - accuracy: 0.9667 - val_loss: 0.0617 - val_accuracy: 0.9200
# Epoch 160/200
# 2/2 - 0s - loss: 0.0327 - accuracy: 0.9667 - val_loss: 0.0703 - val_accuracy: 0.9200
# Epoch 161/200
# 2/2 - 0s - loss: 0.0325 - accuracy: 0.9667 - val_loss: 0.0650 - val_accuracy: 0.9200
# Epoch 162/200
# 2/2 - 0s - loss: 0.0319 - accuracy: 0.9680 - val_loss: 0.0678 - val_accuracy: 0.9200
# Epoch 163/200
# 2/2 - 0s - loss: 0.0321 - accuracy: 0.9680 - val_loss: 0.0668 - val_accuracy: 0.9200
# Epoch 164/200
# 2/2 - 0s - loss: 0.0319 - accuracy: 0.9680 - val_loss: 0.0638 - val_accuracy: 0.9200
# Epoch 165/200
# 2/2 - 0s - loss: 0.0315 - accuracy: 0.9680 - val_loss: 0.0714 - val_accuracy: 0.9200
# Epoch 166/200
# 2/2 - 0s - loss: 0.0327 - accuracy: 0.9667 - val_loss: 0.0582 - val_accuracy: 0.9400
# Epoch 167/200
# 2/2 - 0s - loss: 0.0344 - accuracy: 0.9640 - val_loss: 0.0731 - val_accuracy: 0.9200
# Epoch 168/200
# 2/2 - 0s - loss: 0.0342 - accuracy: 0.9640 - val_loss: 0.0612 - val_accuracy: 0.9400
# Epoch 169/200
# 2/2 - 0s - loss: 0.0324 - accuracy: 0.9680 - val_loss: 0.0670 - val_accuracy: 0.9200
# Epoch 170/200
# 2/2 - 0s - loss: 0.0313 - accuracy: 0.9680 - val_loss: 0.0682 - val_accuracy: 0.9200
# Epoch 171/200
# 2/2 - 0s - loss: 0.0312 - accuracy: 0.9680 - val_loss: 0.0656 - val_accuracy: 0.9200
# Epoch 172/200
# 2/2 - 0s - loss: 0.0311 - accuracy: 0.9693 - val_loss: 0.0675 - val_accuracy: 0.9200
# Epoch 173/200
# 2/2 - 0s - loss: 0.0310 - accuracy: 0.9693 - val_loss: 0.0669 - val_accuracy: 0.9200
# Epoch 174/200
# 2/2 - 0s - loss: 0.0309 - accuracy: 0.9693 - val_loss: 0.0647 - val_accuracy: 0.9200
# Epoch 175/200
# 2/2 - 0s - loss: 0.0311 - accuracy: 0.9693 - val_loss: 0.0665 - val_accuracy: 0.9200
# Epoch 176/200
# 2/2 - 0s - loss: 0.0308 - accuracy: 0.9693 - val_loss: 0.0654 - val_accuracy: 0.9200
# Epoch 177/200
# 2/2 - 0s - loss: 0.0308 - accuracy: 0.9693 - val_loss: 0.0704 - val_accuracy: 0.9200
# Epoch 178/200
# 2/2 - 0s - loss: 0.0312 - accuracy: 0.9680 - val_loss: 0.0629 - val_accuracy: 0.9200
# Epoch 179/200
# 2/2 - 0s - loss: 0.0312 - accuracy: 0.9693 - val_loss: 0.0686 - val_accuracy: 0.9200
# Epoch 180/200
# 2/2 - 0s - loss: 0.0307 - accuracy: 0.9693 - val_loss: 0.0693 - val_accuracy: 0.9200
# Epoch 181/200
# 2/2 - 0s - loss: 0.0309 - accuracy: 0.9693 - val_loss: 0.0689 - val_accuracy: 0.9200
# Epoch 182/200
# 2/2 - 0s - loss: 0.0308 - accuracy: 0.9693 - val_loss: 0.0665 - val_accuracy: 0.9200
# Epoch 183/200
# 2/2 - 0s - loss: 0.0308 - accuracy: 0.9693 - val_loss: 0.0691 - val_accuracy: 0.9200
# Epoch 184/200
# 2/2 - 0s - loss: 0.0309 - accuracy: 0.9680 - val_loss: 0.0679 - val_accuracy: 0.9200
# Epoch 185/200
# 2/2 - 0s - loss: 0.0306 - accuracy: 0.9693 - val_loss: 0.0686 - val_accuracy: 0.9200
# Epoch 186/200
# 2/2 - 0s - loss: 0.0307 - accuracy: 0.9693 - val_loss: 0.0705 - val_accuracy: 0.9200
# Epoch 187/200
# 2/2 - 0s - loss: 0.0305 - accuracy: 0.9693 - val_loss: 0.0642 - val_accuracy: 0.9200
# Epoch 188/200
# 2/2 - 0s - loss: 0.0312 - accuracy: 0.9693 - val_loss: 0.0708 - val_accuracy: 0.9200
# Epoch 189/200
# 2/2 - 0s - loss: 0.0305 - accuracy: 0.9693 - val_loss: 0.0664 - val_accuracy: 0.9200
# Epoch 190/200
# 2/2 - 0s - loss: 0.0305 - accuracy: 0.9693 - val_loss: 0.0718 - val_accuracy: 0.9200
# Epoch 191/200
# 2/2 - 0s - loss: 0.0305 - accuracy: 0.9693 - val_loss: 0.0680 - val_accuracy: 0.9200
# Epoch 192/200
# 2/2 - 0s - loss: 0.0304 - accuracy: 0.9693 - val_loss: 0.0687 - val_accuracy: 0.9200
# Epoch 193/200
# 2/2 - 0s - loss: 0.0303 - accuracy: 0.9693 - val_loss: 0.0726 - val_accuracy: 0.9200
# Epoch 194/200
# 2/2 - 0s - loss: 0.0305 - accuracy: 0.9693 - val_loss: 0.0676 - val_accuracy: 0.9200
# Epoch 195/200
# 2/2 - 0s - loss: 0.0304 - accuracy: 0.9693 - val_loss: 0.0710 - val_accuracy: 0.9200
# Epoch 196/200
# 2/2 - 0s - loss: 0.0304 - accuracy: 0.9693 - val_loss: 0.0713 - val_accuracy: 0.9200
# Epoch 197/200
# 2/2 - 0s - loss: 0.0303 - accuracy: 0.9693 - val_loss: 0.0648 - val_accuracy: 0.9200
# Epoch 198/200
# 2/2 - 0s - loss: 0.0307 - accuracy: 0.9693 - val_loss: 0.0737 - val_accuracy: 0.9200
# Epoch 199/200
# 2/2 - 0s - loss: 0.0309 - accuracy: 0.9693 - val_loss: 0.0615 - val_accuracy: 0.9400
# Epoch 200/200
# 2/2 - 0s - loss: 0.0307 - accuracy: 0.9693 - val_loss: 0.0734 - val_accuracy: 0.9200

# %%
result = model.evaluate(np.array(data_test), np.array(target_test))
# Out:
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0502 - accuracy: 0.9400

# %%
print(result)
# Out:
# [0.05018400773406029, 0.9399999976158142]

# %%
model.save("model.h5")

# %%
from keras.models import load_model
from numpy import loadtxt

# load model
model = load_model('model.h5')
# summarize model.
model.summary()
# load dataset

# evaluate the model
score = model.evaluate(np.array(data_test), np.array(target_test))
print("%s: %.2f%%" % (model.metrics_names[1], score[1]*100))
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 512)               9439232
# _________________________________________________________________
# dense (Dense)                (None, 1024)              525312
# _________________________________________________________________
# activation (Activation)      (None, 1024)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 50)                51250
# _________________________________________________________________
# activation_1 (Activation)    (None, 50)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 2)                 102
# _________________________________________________________________
# activation_2 (Activation)    (None, 2)                 0
# =================================================================
# Total params: 10,015,896
# Trainable params: 10,015,896
# Non-trainable params: 0
# _________________________________________________________________
# 7/7 [==============================] - 1s 12ms/step - loss: 0.0502 - accuracy: 0.9400
# accuracy: 94.00%

# %%
print(score[1])
# Out:
# 0.9399999976158142

# %%
for name, value in zip(model.metrics_names, result):
    print(name, value)
# Out:
# loss 0.05018400773406029
# accuracy 0.9399999976158142

# %%
for name, value in zip(model.metrics_names, result):
    print(name, value)
# Out:
# loss 0.05018400773406029
# accuracy 0.9399999976158142

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.savefig('destination_path.eps', format='eps', dpi=1000)
plt.show()
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.savefig('destination_path1.eps', format='eps', dpi=1000)
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
